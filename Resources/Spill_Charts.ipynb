# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import openpyxl
import folium
import json
import gmaps.datasets
import numpy as np
import re
# from shapely.geometry import Point, Polygon
# import geopandas as gpd
# import descartes
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %matplotlib inline
# %matplotlib notebook

# Import API key
from config import g_map

# Configure gmaps
gmaps.configure(api_key=g_map)

# %% [markdown]
# # Bring in 2010 - Present Data

# %%
# 1. Read the Data_Columns_and_spills into a DataFrame. All sheets
# Unedited excel files
xlfile_2010 = pd.ExcelFile("../Resources/Data_columns_and_spills.xlsx", engine='openpyxl')
spill2010_df = xlfile_2010.parse('2010-Present') #'2010-Present' is the sheet name in the excel file
#spill2010_df is all data all columns

# %%
spill2010_df
# Out:
#      REPORT_RECEIVED_DATE  IYEAR  REPORT_NUMBER  SUPPLEMENTAL_NUMBER  \
# 0              2018-12-10   2018       20180382                32252
# 1              2020-11-06   2020       20200300                34501
# 2              2015-02-24   2015       20150071                21327
# 3              2020-09-13   2020       20200253                35187
# 4              2015-02-06   2015       20150040                20630
# ...                   ...    ...            ...                  ...
# 4635           2018-01-08   2017       20180006                23089
# 4636           2018-05-30   2018       20180156                30565
# 4637           2019-01-03   2018       20190001                31424
# 4638           2019-01-24   2018       20190021                33804
# 4639           2021-03-11   2021       20210060                34982
#
#              REPORT_TYPE  OPERATOR_ID                               NAME  \
# 0     SUPPLEMENTAL FINAL        31130                      DCP MIDSTREAM
# 1         ORIGINAL FINAL        32545  DENBURY GULF COAST PIPELINES, LLC
# 2     SUPPLEMENTAL FINAL        31618  ENTERPRISE PRODUCTS OPERATING LLC
# 3           SUPPLEMENTAL         2552               COLONIAL PIPELINE CO
# 4     SUPPLEMENTAL FINAL        31618  ENTERPRISE PRODUCTS OPERATING LLC
# ...                  ...          ...                                ...
# 4635  SUPPLEMENTAL FINAL         3445         DIXIE PIPELINE COMPANY LLC
# 4636  SUPPLEMENTAL FINAL        30829      ENTERPRISE CRUDE PIPELINE LLC
# 4637      ORIGINAL FINAL        39145  ENBRIDGE STORAGE (CUSHING) L.L.C.
# 4638  SUPPLEMENTAL FINAL          300              PLAINS PIPELINE, L.P.
# 4639      ORIGINAL FINAL          300              PLAINS PIPELINE, L.P.
#
#                OPERATOR_STREET_ADDRESS OPERATOR_CITY_NAME  \
# 0           370 17TH STREET SUITE 2500             DENVER
# 1        5851 LEGACY CIRCLE SUITE 1200              PLANO
# 2               1100 LOUISIANA STREET             HOUSTON
# 3     1185 SANCTUARY PARKWAY SUITE 100         ALPHARETTA
# 4               1100 LOUISIANA STREET             HOUSTON
# ...                                ...                ...
# 4635               1100 LOUISIANA ST.             HOUSTON
# 4636            1100 LOUISIANA STREET             HOUSTON
# 4637            5400 WESTHEIMER COURT             HOUSTON
# 4638     333 CLAY STREET, SUITE 1900              HOUSTON
# 4639     333 CLAY STREET, SUITE 1900              HOUSTON
#
#      OPERATOR_STATE_ABBREVIATION  ...                       PREPARER_TITLE  \
# 0                             CO  ...   SR. PIPELINE COMPLIANCE SPECIALIST
# 1                             TX  ...     REGULATORY COMPLIANCE SPECIALIST
# 2                             TX  ...            SR. COMPLIANCE SPECIALIST
# 3                             GA  ...        MANAGER - PIPELINE COMPLIANCE
# 4                             TX  ...   SR. PIPELINE COMPLIANCE SPECIALIST
# ...                          ...  ...                                  ...
# 4635                          TX  ...         PIPELINE COMPLIANCE ENGINEER
# 4636                          TX  ...  PIPELINE COMPLIANCE SENIOR ENGINEER
# 4637                          TX  ...                SR COMPLIANCE ANALYST
# 4638                          TX  ...            ERC COMPLIANCE SPECIALIST
# 4639                          TX  ...            HSE COMPLIANCE SPECIALIST
#
#                 PREPARER_EMAIL  PREPARER_TELEPHONE  PREPARER_FAX  \
# 0     kdneden@dcpmidstream.com        979-242-6976           NaN
# 1     chad.docekal@denbury.com        972-673-2734           NaN
# 2           mjpavlak@eprod.com        713-381-5897           NaN
# 3          mpiazza@colpipe.com        678-763-5911           NaN
# 4          wnburrell@eprod.com        713-381-3536           NaN
# ...                        ...                 ...           ...
# 4635      lswilliams@eprod.com        713-381-6748           NaN
# 4636      lswilliams@eprod.com        713-381-6748           NaN
# 4637  stacy.soine@enbridge.com        715-395-3620           NaN
# 4638      nagonzalez@paalp.com        713-646-4376           NaN
# 4639      nagonzalez@paalp.com        713-646-4376           NaN
#
#      PREPARED_DATE AUTHORIZER_NAME                     AUTHORIZER_TITLE  \
# 0       2019-06-07   JOHN PONTIOUS          MANAGER PIPELINE COMPLIANCE
# 1       2020-11-06  DAVID SHEPPARD   SENIOR VICE PRESIDENT - OPERATIONS
# 2       2016-04-21  MICHAEL PAVLAK            SR. COMPLIANCE SPECIALIST
# 3       2021-04-17     MARK PIAZZA        MANAGER - PIPELINE COMPLIANCE
# 4       2015-07-29    NEAL BURRELL   SR. PIPELINE COMPLIANCE SPECIALIST
# ...            ...             ...                                  ...
# 4635    2018-02-01     SUZIE DAVIS                   COMPLIANCE MANAGER
# 4636    2018-06-28  LEANN WILLIAMS  PIPELINE COMPLIANCE SENIOR ENGINEER
# 4637    2019-01-03    RON CARLBERG    SUPERVISOR US PIPELINE COMPLIANCE
# 4638    2020-05-27   NGIABI GICUHI                     ERC MGR DIRECTOR
# 4639    2021-03-11   NGIABI GICUHI                    HSE MGR. DIRECTOR
#
#      AUTHORIZER_TELEPHONE             AUTHORIZER_EMAIL  \
# 0            405-605-3859  jdpontious@dcpmidstream.com
# 1            972-673-2038   david.sheppard@denbury.com
# 2            713-381-5897           mjpavlak@eprod.com
# 3            678-763-5911          mpiazza@colpipe.com
# 4            713-381-3536          wnburrell@eprod.com
# ...                   ...                          ...
# 4635         713-381-5585            smdavis@eprod.com
# 4636         713-381-6748         lswilliams@eprod.com
# 4637         715-395-3619    ron.carlberg@enbridge.com
# 4638         713-646-4336            ngicuhi@paalp.com
# 4639         713-646-4336            ngicuhi@paalp.com
#
#                                               NARRATIVE
# 0     DCP CONTRACT LINE LOCATOR GUADALUPE VALDES PRO...
# 1     ON 10/7/2020 AT 17:31, DENBURY BEGAN BLOWDOWN ...
# 2     AT APPROXIMATELY 9:40 A.M. C.S.T. ON JANUARY 2...
# 3     ON 8/14/2020 AT 18:20, A COLONIAL EMPLOYEE WAS...
# 4     ON 1/10/2015 AT 20:45 HRS, PIPELINE CONTROL DI...
# ...                                                 ...
# 4635  PUMP SHUT DOWN DUE TO HIGH BEARING TEMPERATURE...
# 4636  DURING TANK REPAIRS, CONTRACT EMPLOYEE REMOVED...
# 4637  ON DECEMBER 4, 2018 AT APPROXIMATELY 20:10 CST...
# 4638  ON 08/28/2018 AT ~7:40 A.M., THE PRIMARY AND S...
# 4639  ON 02/09/2021 AT ~11:33 A.M., TANK 326 AT HEND...
#
# [4640 rows x 588 columns]

# %%
spill2010_df.columns
# Out:
# Index(['REPORT_RECEIVED_DATE', 'IYEAR', 'REPORT_NUMBER', 'SUPPLEMENTAL_NUMBER',
#        'REPORT_TYPE', 'OPERATOR_ID', 'NAME', 'OPERATOR_STREET_ADDRESS',
#        'OPERATOR_CITY_NAME', 'OPERATOR_STATE_ABBREVIATION',
#        ...
#        'PREPARER_TITLE', 'PREPARER_EMAIL', 'PREPARER_TELEPHONE',
#        'PREPARER_FAX', 'PREPARED_DATE', 'AUTHORIZER_NAME', 'AUTHORIZER_TITLE',
#        'AUTHORIZER_TELEPHONE', 'AUTHORIZER_EMAIL', 'NARRATIVE'],
#       dtype='object', length=588)

# %% [markdown]
# ## Create Bar Chart for Years (2010-Present)
# ### Groupby year

# %%
spill2010_per_yr = spill2010_df.groupby(['IYEAR']).count()['REPORT_NUMBER']
spill2010_per_yr
# Out:
# IYEAR
# 2010    350
# 2011    344
# 2012    366
# 2013    400
# 2014    455
# 2015    460
# 2016    420
# 2017    415
# 2018    405
# 2019    384
# 2020    333
# 2021    308
# Name: REPORT_NUMBER, dtype: int64

# %%
spill2010_per_yr.to_json('spill2010_charts.json')

# %%
year = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
plt.bar(year, spill2010_per_yr)
plt.title("Spills per Year (2010-Nov 2021)", fontsize=20)
plt.ylabel("Spill Count", fontsize=12)
plt.xlabel("Year", fontsize=12)
plt.grid(True)
# lgnd = plt.legend(fontsize="12", mode="Expanded", scatterpoints=1, loc="best", 
#                  title="Spills")
# lgnd.legendHandles[0]._sizes = [75]
# lgnd.legendHandles[1]._sizes = [75]
# lgnd.legendHandles[2]._sizes = [75]
# lgnd.get_title().set_fontsize(12)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Pie Chart of Causes 2010-Present

# %%
failure_count = spill2010_df.groupby(['CAUSE']).count()['REPORT_NUMBER']
failure_count
# Out:
# CAUSE
# CORROSION FAILURE                    944
# EQUIPMENT FAILURE                   2124
# EXCAVATION DAMAGE                    165
# INCORRECT OPERATION                  674
# MATERIAL FAILURE OF PIPE OR WELD     310
# NATURAL FORCE DAMAGE                 217
# OTHER INCIDENT CAUSE                 114
# OTHER OUTSIDE FORCE DAMAGE            91
# Name: REPORT_NUMBER, dtype: int64

# %%
failure_count2010 = spill2010_df.groupby(['CAUSE']).count()['REPORT_NUMBER']
failure_count2010_dict = failure_count2010.to_dict()
json_failure_count2010 = json.dumps(failure_count2010_dict, indent = 4)
with open('failure_count2010_dict.json','w') as data:
    data.write(json_failure_count2010)

# %%
failure_modes = [
    'CORROSION FAILURE',
    'EQUIPMENT FAILURE',
    'EXCAVATION DAMAGE',
    'INCORRECT OPERATION',
    'MATERIAL FAILURE OF PIPE OR WELD',
    'NATURAL FORCE DAMAGE',
    'OTHER INCIDENT CAUSE',
    'OTHER OUTSIDE FORCE DAMAGE'
    ]

# %%
explode = [0, 0.2, 0, 0, 0, 0, 0, 0]
colors = ["red", "orange", "green", "lightcoral", "lightskyblue", "white", "purple", "cyan"]

# %%
plt.pie(failure_count, explode=explode, labels=failure_modes,
       colors=colors, autopct="%1.1f%%", shadow=True, startangle=0)
# Out:
# <img src="data:image/png;base64,..." width="432">
# ([<matplotlib.patches.Wedge at 0x2c734151788>,
#   <matplotlib.patches.Wedge at 0x2c73415ad48>,
#   <matplotlib.patches.Wedge at 0x2c7349a7048>,
#   <matplotlib.patches.Wedge at 0x2c7349a7cc8>,
#   <matplotlib.patches.Wedge at 0x2c7349ac988>,
#   <matplotlib.patches.Wedge at 0x2c7349b1688>,
#   <matplotlib.patches.Wedge at 0x2c7349b6348>,
#   <matplotlib.patches.Wedge at 0x2c7349b6fc8>],
#  [Text(0.8827719174300638, 0.6562878498013268, 'CORROSION FAILURE'),
#   Text(-1.1845578644081238, 0.5355582749513498, 'EQUIPMENT FAILURE'),
#   Text(-0.473769405283116, -0.9927449574879154, 'EXCAVATION DAMAGE'),
#   Text(0.13486554816160112, -1.0917010964174538, 'INCORRECT OPERATION'),
#   Text(0.7808404174597765, -0.7747827066095643, 'MATERIAL FAILURE OF PIPE OR WELD'),
#   Text(1.002318203567805, -0.45316467072865296, 'NATURAL FORCE DAMAGE'),
#   Text(1.0779736763578422, -0.2190268318712538, 'OTHER INCIDENT CAUSE'),
#   Text(1.0979118684086184, -0.06774606414764602, 'OTHER OUTSIDE FORCE DAMAGE')],
#  [Text(0.4815119549618529, 0.35797519080072365, '20.3%'),
#   Text(-0.7289586857896144, 0.3295743230469844, '45.8%'),
#   Text(-0.25841967560897233, -0.5414972495388628, '3.6%'),
#   Text(0.07356302626996424, -0.5954733253186112, '14.5%'),
#   Text(0.42591295497805987, -0.42260874905976226, '6.7%'),
#   Text(0.5467190201278936, -0.24718072948835612, '4.7%'),
#   Text(0.587985641649732, -0.11946918102068388, '2.5%'),
#   Text(0.5988610191319735, -0.03695239862598873, '2.0%')])

# %% [markdown]
# # Bring in 2002-2009 Data

# %%
# Read the Data_Columns_and_spills into a DataFrame. All sheets
# Unedited excel files
xlfile_2002 = pd.ExcelFile("../Resources/Data_columns_and_spills.xlsx", engine='openpyxl')
spill2002_df = xlfile_2002.parse('2002-2010') #'2002-2010' is the sheet name in the excel file
#spill2002_df is all data all columns

# %%
spill2002_df
# Out:
#       IYEAR  OPERATOR_ID     RPTID  OWNER_OPERATOR_ID  \
# 0      2002        19237  20020037                NaN
# 1      2002        25146  20020038                NaN
# 2      2002        12628  20020039                NaN
# 3      2002         2731  20020040                NaN
# 4      2002         4472  20020041                NaN
# ...     ...          ...       ...                ...
# 3025   2009        10012  20090382                NaN
# 3026   2007        32147  20090383                NaN
# 3027   2006        32147  20090384                NaN
# 3028   2009        32147  20090385                NaN
# 3029   2009        22442  20090386                NaN
#
#                                             NAME  \
# 0                   TE PRODUCTS PIPELINE CO., LP
# 1                       EQUISTAR CHEMICALS, L.P.
# 2                              MOBIL PIPELINE CO
# 3                            CHEVRON PIPELINE CO
# 4            KINDER MORGAN ENERGY PARTNERS, L.P.
# ...                                          ...
# 3025  NUSTAR PIPELINE OPERATING PARTNERSHIP L.P.
# 3026                      MARATHON PIPE LINE LLC
# 3027                      MARATHON PIPE LINE LLC
# 3028                      MARATHON PIPE LINE LLC
# 3029                 WEST TEXAS GULF PIPELINE CO
#
#                                   OPSTREET      OPCITY   OPCOUNTY OPSTATE  \
# 0                       2929 ALLEN PARKWAY     HOUSTON     HARRIS      TX
# 1                              PO BOX 1847       ALVIN   BRAZORIA      TX
# 2                          800 BELL STREET     HOUSTON     HARRIS      TX
# 3                          2811 HAYES ROAD     HOUSTON     HARRIS      TX
# 4                500 DALLAS ST, SUITE 1000     HOUSTON     HARRIS      TX
# ...                                    ...         ...        ...     ...
# 3025     7340 W. 21ST STREET N., SUITE 200     WICHITA   SEDGWICK      KS
# 3026                 539 SOUTH MAIN STREET     FINDLAY    HANCOCK      OH
# 3027                 539 SOUTH MAIN STREET     FINDLAY    HANCOCK      OH
# 3028                 539 SOUTH MAIN STREET     FINDLAY    HANCOCK      OH
# 3029  ONE FLUOR DANIEL DR. BLDG. A LEVEL 3  SUGAR LAND  FORT BEND      TX
#
#       OPZIP  ...  IO_DRUG IO_ALCO  \
# 0     77019  ...      NaN     NaN
# 1     77512  ...      NaN     NaN
# 2     77002  ...      0.0     0.0
# 3     77082  ...      NaN     NaN
# 4     77002  ...      NaN     NaN
# ...     ...  ...      ...     ...
# 3025  67205  ...      NaN     NaN
# 3026  45840  ...      0.0     0.0
# 3027  45840  ...      0.0     0.0
# 3028  45840  ...      NaN     NaN
# 3029  77478  ...      NaN     NaN
#
#                                                    MISC UNKNOWN UNKNOWN_TXT  \
# 0                                                   NaN     NaN         NaN
# 1                                                   NaN     NaN         NaN
# 2                                                   NaN     NaN         NaN
# 3                                                   NaN     NaN         NaN
# 4                                                   NaN     NaN         NaN
# ...                                                 ...     ...         ...
# 3025                                                NaN     NaN         NaN
# 3026                                                NaN     NaN         NaN
# 3027                                                NaN     NaN         NaN
# 3028  RESIDUAL PRODUCT IN THE LINE IGNITED FOLLOWING...     NaN         NaN
# 3029  IGNITED VAPORS WHILE BEVELING PIPE WITH AN ACE...     NaN         NaN
#
#                                                   PNAME        PTEL  \
# 0                                           JLYNN STOUT  7137593614
# 1                                          GREG LEBLANC  7138446942
# 2                                     STEVEN J ROBENOLT  7136562651
# 3                                            R A THORPE  2815963571
# 4                                     JAIME A HERNANDEZ  7133699443
# ...                                                 ...         ...
# 3025                                  DANIEL J. TIBBITS  3167217056
# 3026                                      MANDI KUHLMAN  4194214037
# 3027                                      MANDI KUHLMAN  4194214037
# 3028                                      MANDI KUHLMAN  4194214037
# 3029  KENNETH DAVID BORN, AREA DOT COMPLIANCE SUPERV...  2816376497
#
#                                  PEMAIL          PFAX  \
# 0                    JPSTOUT@TEPPCO.COM  7.137594e+09
# 1      GREGORY.LEBLANC@EQUISTARCHEM.COM  7.138447e+09
# 2      STEVEN.J.ROBENOLT@EXXONMOBIL.COM  7.136568e+09
# 3            RATHORPE@CHEVRONTEXACO.COM  2.815964e+09
# 4     JAIME_HERNANDEZ@KINKDERMORGAN.COM  7.134954e+09
# ...                                 ...           ...
# 3025       DAN.TIBBITS@NUSTARENERGY.COM  3.167739e+09
# 3026    MMKUHLMAN@MARATHONPETROLEUM.COM  4.194214e+09
# 3027    MMKUHLMAN@MARATHONPETROLEUM.COM  4.194214e+09
# 3028    MMKUHLMAN@MARATHONPETROLEUM.COM  4.194214e+09
# 3029         KDBORN@SUNOCOLOGISTICS.COM  8.666199e+09
#
#                                               NARRATIVE
# 0                                                   NaN
# 1     REGARDING PART C5:  SECTIONS OF THIS LINE WERE...
# 2     ON JANUARY 24,2002 MOBIL PIPELINE COMPANY INCU...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3025                                                NaN
# 3026  DURING INSTALLATION OF NEW 16” CONTROL VALVE A...
# 3027  WHILE PREPARING TO INSTALL A NEW FABRICATION, ...
# 3028  FOLLOWING A NITROGEN PURGE, COLD CUTS WERE UTI...
# 3029  AN IGNITION OF VAPORS OCCURRED WHILE BEVELING ...
#
# [3030 rows x 259 columns]

# %% [markdown]
# ## Bar Graph Incidents per Year 2002-2009

# %%
spill2002_per_yr = spill2002_df.groupby(['IYEAR']).count()['RPTID']
spill2002_per_yr
# Out:
# IYEAR
# 2002    448
# 2003    432
# 2004    377
# 2005    369
# 2006    354
# 2007    332
# 2008    376
# 2009    342
# Name: RPTID, dtype: int64

# %%
spill2002_per_yr.to_json('spill2002_charts.json')

# %%
year = [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

# %%
plt.bar(year, spill2002_per_yr)
plt.title("Spills per Year (2002-2009)", fontsize=20)
plt.ylabel("Spill Count", fontsize=12)
plt.xlabel("Year", fontsize=12)
plt.grid(True)
# lgnd = plt.legend(fontsize="12", mode="Expanded", scatterpoints=1, loc="best", 
#                  title="Spills")
# lgnd.legendHandles[0]._sizes = [75]
# lgnd.legendHandles[1]._sizes = [75]
# lgnd.legendHandles[2]._sizes = [75]
# lgnd.get_title().set_fontsize(12)

# %%
failure_count2002 = spill2002_df.groupby(['GEN_CAUSE_TXT']).count()['RPTID']
failure_count2002_dict = failure_count2002.to_dict()
json_failure_count2002 = json.dumps(failure_count2002_dict, indent = 4)
with open('failure_count2002_dict.json','w') as data:
    data.write(json_failure_count2002)

# %%
failure_count2002.to_json('failure_count2002.json')

# %%
failure_modes2002 = [
    'CORROSION',
    'EQUIPMENT',
    'EXCAVATION DAMAGE',
    'INCORRECT OPERATION',
    'MATERIAL AND/OR WELD FAILURES',
    'NATURAL FORCES',
    'OTHER',
    'OTHER OUTSIDE FORCE DAMAGE'
    ]

# %%
explode = [0, 0.2, 0, 0, 0, 0, 0, 0]
colors = ["red", "orange", "green", "lightcoral", "lightskyblue", "white", "purple", "cyan"]

# %%
plt.pie(failure_count2002, explode=explode, labels=failure_modes2002,
       colors=colors, autopct="%1.1f%%", shadow=True, startangle=0)
# Out:
# <img src="data:image/png;base64,..." width="432">
# ([<matplotlib.patches.Wedge at 0x19554cdc7c8>,
#   <matplotlib.patches.Wedge at 0x195553c7288>,
#   <matplotlib.patches.Wedge at 0x19550f636c8>,
#   <matplotlib.patches.Wedge at 0x19552177c48>,
#   <matplotlib.patches.Wedge at 0x19554cf1ac8>,
#   <matplotlib.patches.Wedge at 0x195553c0e88>,
#   <matplotlib.patches.Wedge at 0x19552128f48>,
#   <matplotlib.patches.Wedge at 0x19550f46988>],
#  [Text(0.8281209309016754, 0.72402743304556, 'CORROSION'),
#   Text(-1.055044044775964, 0.7595275265471122, 'EQUIPMENT'),
#   Text(-0.8778188747088103, -0.6628981997297612, 'EXCAVATION DAMAGE'),
#   Text(-0.428063108076709, -1.0132926406047307, 'INCORRECT OPERATION'),
#   Text(0.35768113894352643, -1.040223150503805, 'MATERIAL AND/OR WELD FAILURES'),
#   Text(0.8588946373412688, -0.6872408616681712, 'NATURAL FORCES'),
#   Text(1.0402232258529636, -0.35768091980989786, 'OTHER'),
#   Text(1.0966670667302716, -0.08556485697541025, 'OTHER OUTSIDE FORCE DAMAGE')],
#  [Text(0.4517023259463683, 0.39492405438848727, '22.9%'),
#   Text(-0.6492578737082855, 0.4674015547982228, '34.4%'),
#   Text(-0.4788102952957146, -0.3615808362162333, '6.0%'),
#   Text(-0.23348896804184122, -0.5527050766934893, '10.6%'),
#   Text(0.1950988030601053, -0.5673944457293482, '12.6%'),
#   Text(0.4684879840043284, -0.3748586518190024, '5.4%'),
#   Text(0.5673944868288892, -0.19509868353267154, '5.6%'),
#   Text(0.5981820363983299, -0.046671740168405584, '2.5%')])
