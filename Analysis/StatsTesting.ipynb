# %%
#import dependencies
import pandas as pd
import numpy as np
import statsmodels.api as sm

#import data
df = pd.read_excel('TestingDataForStats.xlsx')
df
# Out:
#      REPORT_NUMBER    NAME DATETIME_OF_INCIDENT  LOCATION_LATITUDE  \
# 0         20210333       Q  1983-01-01 00:00:00             40.676
# 1         20210334       W  1983-01-02 00:00:00             41.676
# 2         20210335       E  1983-01-03 00:00:00             42.676
# 3         20210336       R  1983-01-04 00:00:00             43.676
# 4         20210337       T  1983-01-05 00:00:00             44.676
# ..             ...     ...                  ...                ...
# 194       20210527     WET  2005-12-30 00:00:00             40.987
# 195       20210528   WHAAT  2005-12-31 00:00:00             41.987
# 196       20210529     WHO  2006-01-01 00:00:00             42.987
# 197       20210530  CANCUN  2006-01-02 00:00:00             43.987
# 198       20210531    BASH  2006-01-03 00:00:00             44.987
#
#      LOCATION_LONGITUDE                            COMMODITY_RELEASED_TYPE  \
# 0              -106.495  REFINED AND/OR PETROLEUM PRODUCT (NON-HVL) WHI...
# ...

# %%
barrels_summary = sm.describe(df['TOTAL_BBLS_RELEASED'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7468/1708258081.py in <module>
# ----> 1 barrels_summary = sm.describe(df['TOTAL_BBLS_RELEASED'])
#
# AttributeError: module 'statsmodels.api' has no attribute 'describe'
